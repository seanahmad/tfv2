# %% [markdown]
# ## Task: To predict patient glucose levels using a Keras-based neural network.
#
# ### Original data: https://data.world/uci/pima-indians-diabetes

# %% [markdown]
# ## Install TensorFlow

# %%
devtools::install_github("rstudio/tensorflow")
# Out:
# Downloading GitHub repo rstudio/tensorflow@master
# reticulate (NA -> 6b94066a4...) [GitHub]
# tfruns     (NA -> 1.4         ) [CRAN]
# Downloading GitHub repo rstudio/reticulate@master
# ✔  checking for file ‘/tmp/RtmpUeu48G/remotesee5c89a3/rstudio-reticulate-6b94066/DESCRIPTION’
# ─  preparing ‘reticulate’:
# ✔  checking DESCRIPTION meta-information
# ─  cleaning src
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  building ‘reticulate_1.13.0-9000.tar.gz’
# Installing 1 packages: tfruns
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Skipping install of 'reticulate' from a github remote, the SHA1 (6b94066a) has not changed since last install.
#   Use `force = TRUE` to force installation
# ✔  checking for file ‘/tmp/RtmpUeu48G/remotese64f33819/rstudio-tensorflow-1102ce9/DESCRIPTION’
# ─  preparing ‘tensorflow’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  building ‘tensorflow_1.14.0.9000.tar.gz’

# %% [markdown]
# ## Install Keras

# %%
devtools::install_github("rstudio/keras")
# Out:
# Downloading GitHub repo rstudio/keras@master
# ✔  checking for file ‘/tmp/RtmpUeu48G/remotese47c3107/rstudio-keras-95ea0b5/DESCRIPTION’
# ─  preparing ‘keras’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts (432ms)
# ─  checking for empty or unneeded directories
#    Removed empty directory ‘keras/man-roxygen’
# ─  building ‘keras_2.2.4.1.9001.tar.gz’

# %% [markdown]
# ## Load TensorFlow library

# %%
library(tensorflow)
#install_tensorflow()

# %% [markdown]
# ## Load Keras library and normalize data

# %%
library(keras)
diabetes1<-read.csv("pima-indians-diabetes1.csv")

# %% [markdown]
# ## Max-Min Normalization

# %%
normalize <- function(x) {
  return ((x - min(x)) / (max(x) - min(x)))
}

maxmindf <- as.data.frame(lapply(diabetes1, normalize))
attach(maxmindf)
maxmindf<-as.matrix(maxmindf)

# %% [markdown]
# ## Train-validation split

# %%
ind <- sample(2, nrow(maxmindf), replace=TRUE, prob = c(0.7,0.3))

# %% [markdown]
# ## Build X_train, y_train, X_val, y_val

# %%
X_train <- maxmindf[ind==1, 1:8]
X_val <- maxmindf[ind==2, 1:8]
y_train <- maxmindf[ind==1, 9]
y_val <- maxmindf[ind==2, 9]

# %% [markdown]
# ## Sequential model

# %%
model <- keras_model_sequential() 
model %>% 
  layer_dense(units = 12, activation = 'relu', kernel_initializer='RandomNormal', input_shape = c(8)) %>% 
  layer_dense(units = 8, activation = 'relu') %>%
  layer_dense(units = 1, activation = 'linear')

summary(model)
# Out:
# Model: "sequential"
# ________________________________________________________________________________
# Layer (type)                        Output Shape                    Param #
# ================================================================================
# dense (Dense)                       (None, 12)                      108
# ________________________________________________________________________________
# dense_1 (Dense)                     (None, 8)                       104
# ________________________________________________________________________________
# dense_2 (Dense)                     (None, 1)                       9
# ================================================================================
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# ________________________________________________________________________________

# %% [markdown]
# ## Model compilation with mean squared error used as loss function
#
# ### Model trained over 150 epochs

# %%
model %>% compile(
  loss = 'mean_squared_error',
  optimizer = 'adam',
  metrics = c('mae')
)

history <- model %>% fit(
  X_train, y_train, 
  epochs = 150, batch_size = 50, 
  validation_split = 0.2
)

# %% [markdown]
# ### Model evaluation

# %%
model %>% evaluate(X_val, y_val)
model
pred <- data.frame(y = predict(model, as.matrix(X_val)))
predicted=pred$y * abs(diff(range(diabetes1$Glucose))) + min(diabetes1$Glucose)
actual=y_val * abs(diff(range(diabetes1$Glucose))) + min(diabetes1$Glucose)
df<-data.frame(predicted,actual)
attach(df)
# Out:
# $loss
# [1] 0.02728666
#
# $mae
# [1] 0.1330932
# Model
# Model: "sequential"
# ________________________________________________________________________________
# Layer (type)                        Output Shape                    Param #
# ================================================================================
# dense (Dense)                       (None, 12)                      108
# ________________________________________________________________________________
# dense_1 (Dense)                     (None, 8)                       104
# ________________________________________________________________________________
# dense_2 (Dense)                     (None, 1)                       9
# ================================================================================
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# ________________________________________________________________________________
# The following objects are masked _by_ .GlobalEnv:
#
#     actual, predicted

# %% [markdown]
# ## Glucose level predictions

# %%
predicted=as.matrix(predicted)
predicted
# Out:
#       [,1]
#  [1,] 108.33714
#  [2,] 129.56989
#  [3,] 125.64662
#  [4,] 108.13061
#  [5,] 111.11950
#  [6,] 113.20711
#  [7,] 106.49417
#  [8,]  96.00997
#  [9,] 153.15887
# [10,] 111.73989
# [11,] 147.33566
# [12,] 111.14526
# [13,] 132.58995
# [14,] 120.15491
# [15,] 126.16778
# [16,] 106.00129
# [17,] 100.47839
# [18,] 139.75460
# [19,]  99.79215
# [20,] 160.57252
# [21,] 135.04797
# [22,] 122.15088
# [23,] 104.30596
# [24,] 119.24519
# [25,] 137.37336
# [26,] 109.15456
# [27,] 128.81795
# [28,] 124.42288
# [29,] 106.57136
# [30,] 110.27540
# [31,] ⋮
# [32,] 130.81550
# [33,] 125.54569
# [34,] 109.75826
# [35,] 162.48922
# [36,] 103.28878
# [37,] 112.21361
# [38,] 150.70432
# [39,] 146.19147
# [40,] 112.49470
# [41,]  97.48755
# [42,] 146.12621
# [43,] 141.12702
# [44,]  99.49212
# [45,] 134.57841
# [46,] 105.30659
# [47,] 110.67284
# [48,] 123.29840
# [49,] 143.44139
# [50,] 112.52859
# [51,] 127.30724
# [52,] 100.75338
# [53,] 110.48765
# [54,] 137.11832
# [55,]  97.88199
# [56,]  96.62246
# [57,] 108.10348
# [58,] 137.06514
# [59,] 105.70535
# [60,] 133.51705
# [61,] 137.56479

# %%
actual
# Out:
#   [1]  91 197  67  87  85 138  98 128 146 103 108 125 141 154 107 122  96 180
#  [19]  77 177 100 136 114 102 171 122 109 110  97  83 179 162 143  96 124 119
#  [37] 112 128 194  90 146 107 141  74  57 105  84 187 111 119 143 145 126 139
#  [55] 146 101 101 184  93 125  95 122  99 136 130 114  84  86 119  90  97  87
#  [73] 168 102 120 105  90  92 159 180 133  94  85 107 134 126 135 134 127 105
#  [91] 196 144 170  84 100 102 123 105 135 193  86 112 130 125 163 108 182  99
# [109] 184 133 100 151  85 105 148 124 117 152 119 162 132 140 138 129 134 124
# [127] 146 152 123 128  85 151 100  87 117 107 111 125 124 120 155 136 112 100
# [145]  99 139 189  95  61 124  75 127  81  87 131 129 150 187  95 111 122 196
# [163] 115  80 161 135  71 118  92  84  99 115 103 103  74 137 139 111 100  97
# [181] 159 109 144 136

# %% [markdown]
# ## Mean percentage error
#
# ### Percentage difference between predicted and actual values

# %%
mpe=((predicted-actual)/actual)
mean(mpe)*100
# Out:
# [1] 5.00391

# %% [markdown]
# ## EXERCISE
#
# ### pima-indians-diabetes2.csv contains the predictor variables for the test set.
#
# ### pima-indians-diabetes3.csv contains the dependent variables (or glucose readings) for the test set.
#
# ### Your task is to use the existing model to generate new predictions for this test set and calculate the mean percentage error on these new predictions.

# %%
diabetes2<-read.csv("pima-indians-diabetes2.csv")
# Out:
# The following objects are masked from maxmindf:
#
#     Age, BloodPressure, BMI, DiabetesPedigreeFunction, Insulin,
#     Outcome, Pregnancies, SkinThickness

# %% [markdown]
# ## Max-Min Normalization

# %%
normalize <- function(x) {
  return ((x - min(x)) / (max(x) - min(x)))
}

maxmindf2 <- as.data.frame(lapply(diabetes2, normalize))
attach(maxmindf2)

# %% [markdown]
# ## Using the predict function in R, generate predictions (pred_test) for the Glucose variable using maxmindf2.

# %%
pred_test <- # Complete this line...
predicted_test = pred_test$y * abs(diff(range(diabetes1$Glucose))) + min(diabetes1$Glucose)
predicted_test
# Out:
# Error in eval(expr, envir, enclos): object 'pred_test' not found
# Traceback:

# %% [markdown]
# ## Loading test set - or unseen data for this purpose.

# %%
diabetes3<-read.csv("pima-indians-diabetes3.csv")
diabetes3
# Out:
#     Glucose
# 1    97
# 2    83
# 3   130
# 4   128
# 5   149
# 6   144
# 7   119
# 8   108
# 9   120
# 10  120
# 11  114
# 12  127
# 13  162
# 14  106
# 15   90
# 16   93
# 17  106
# 18  112
# 19  147
# 20  111
# 21  107
# 22  153
# 23  110
# 24  136
# 25  136
# 26  195
# 27  101
# 28   88
# 29  175
# 30  145
# ⋮   ⋮
# 124 102
# 125 102
# 126 106
# 127 174
# 128 121
# 129 142
# 130 145
# 131  80
# 132 112
# 133 122
# 134  95
# 135 141
# 136 106
# 137 101
# 138 140
# 139  94
# 140 111
# 141 129
# 142 112
# 143  94
# 144 156
# 145 128
# 146 162
# 147 158
# 148 132
# 149 168
# 150 129
# 151 137
# 152 199
# 153 138

# %% [markdown]
# ## Compare predicted values with actual values.

# %%
actual_test = diabetes3$Glucose
df2<-data.frame(predicted_test,actual_test)
attach(df2)
df2
# Out:
# Error in data.frame(predicted_test, actual_test): object 'predicted_test' not found
# Traceback:
#
# 1. data.frame(predicted_test, actual_test)

# %% [markdown]
# ## Mean percentage error calculation

# %%
mpe2= # Insert the formula for calculating the mean percentage error here...
mean(mpe2)*100
# Out:
# Error in mean(mpe2): object 'mpe2' not found
# Traceback:
#
# 1. mean(mpe2)
