# %% [markdown]
# ## Task: To predict patient glucose levels using a Keras-based neural network.
#
# ### Original data: https://data.world/uci/pima-indians-diabetes

# %% [markdown]
# ## Install TensorFlow

# %%
devtools::install_github("rstudio/tensorflow")

# %% [markdown]
# ## Install Keras

# %%
devtools::install_github("rstudio/keras")

# %% [markdown]
# ## Load TensorFlow library

# %%
library(tensorflow)
#install_tensorflow()

# %% [markdown]
# ## Load Keras library and normalize data

# %%
library(keras)
diabetes1<-read.csv("pima-indians-diabetes1.csv")

# %% [markdown]
# ## Max-Min Normalization

# %%
normalize <- function(x) {
  return ((x - min(x)) / (max(x) - min(x)))
}

maxmindf <- as.data.frame(lapply(diabetes1, normalize))
attach(maxmindf)
maxmindf<-as.matrix(maxmindf)

# %% [markdown]
# ## Train-validation split

# %%
ind <- sample(2, nrow(maxmindf), replace=TRUE, prob = c(0.7,0.3))

## Build X_train, y_train, X_val, y_val
X_train <- maxmindf[ind==1, 1:8]
X_val <- maxmindf[ind==2, 1:8]
y_train <- maxmindf[ind==1, 9]
y_val <- maxmindf[ind==2, 9]

# %% [markdown]
# ## Sequential model

# %%
model <- keras_model_sequential() 
model %>% 
  layer_dense(units = 12, activation = 'relu', kernel_initializer='RandomNormal', input_shape = c(8)) %>% 
  layer_dense(units = 8, activation = 'relu') %>%
  layer_dense(units = 1, activation = 'linear')

summary(model)
# Out:
# ________________________________________________________________________________
# Layer (type)                        Output Shape                    Param #
# ================================================================================
# dense (Dense)                       (None, 12)                      108
# ________________________________________________________________________________
# dense_1 (Dense)                     (None, 8)                       104
# ________________________________________________________________________________
# dense_2 (Dense)                     (None, 1)                       9
# ================================================================================
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# ________________________________________________________________________________

# %% [markdown]
# ## Model compilation with mean squared error used as loss function
#
# ### Model trained over 150 epochs

# %%
model %>% compile(
  loss = 'mean_squared_error',
  optimizer = 'adam',
  metrics = c('mae')
)

history <- model %>% fit(
  X_train, y_train, 
  epochs = 150, batch_size = 50, 
  validation_split = 0.2
)

# %% [markdown]
# ### Model evaluation

# %%
model %>% evaluate(X_val, y_val)
model
pred <- data.frame(y = predict(model, as.matrix(X_val)))
predicted=pred$y * abs(diff(range(diabetes1$Glucose))) + min(diabetes1$Glucose)
actual=y_val * abs(diff(range(diabetes1$Glucose))) + min(diabetes1$Glucose)
df<-data.frame(predicted,actual)
attach(df)
# Out:
# $loss
# [1] 0.02582347
#
# $mean_absolute_error
# [1] 0.1300376
# Model
# ________________________________________________________________________________
# Layer (type)                        Output Shape                    Param #
# ================================================================================
# dense (Dense)                       (None, 12)                      108
# ________________________________________________________________________________
# dense_1 (Dense)                     (None, 8)                       104
# ________________________________________________________________________________
# dense_2 (Dense)                     (None, 1)                       9
# ================================================================================
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# ________________________________________________________________________________
# The following objects are masked _by_ .GlobalEnv:
#
#     actual, predicted

# %% [markdown]
# ## Glucose level predictions

# %%
predicted=as.matrix(predicted)
predicted
# Out:
#       [,1]
#  [1,] 115.03139
#  [2,] 155.63502
#  [3,] 120.48860
#  [4,] 103.43557
#  [5,] 107.22563
#  [6,]  98.38659
#  [7,] 145.38961
#  [8,] 117.22818
#  [9,] 144.96535
# [10,] 113.74861
# [11,] 101.05641
# [12,] 146.51342
# [13,] 143.23092
# [14,] 156.02339
# [15,] 116.61230
# [16,] 141.07473
# [17,] 118.01894
# [18,] 119.29984
# [19,] 152.23846
# [20,] 136.95991
# [21,] 166.19492
# [22,] 141.72885
# [23,] 111.58298
# [24,] 109.80412
# [25,] 163.44671
# [26,] 152.25162
# [27,] 146.71296
# [28,] 117.95208
# [29,] 105.01873
# [30,] 149.16569
# [31,] ⋮
# [32,] 116.65601
# [33,] 146.74918
# [34,] 121.00611
# [35,] 116.16368
# [36,] 117.89561
# [37,] 126.64741
# [38,] 105.57761
# [39,] 112.90692
# [40,] 106.42917
# [41,] 116.65576
# [42,] 160.64765
# [43,]  96.02874
# [44,] 104.16038
# [45,] 101.81049
# [46,] 109.31153
# [47,] 127.18388
# [48,] 111.42107
# [49,] 122.14432
# [50,] 108.22648
# [51,] 124.82707
# [52,] 107.20846
# [53,] 156.63913
# [54,] 147.21291
# [55,] 105.33748
# [56,] 164.28291
# [57,] 104.39099
# [58,] 117.44477
# [59,] 130.81131
# [60,] 138.61261
# [61,] 147.91620

# %%
actual
# Out:
#   [1] 137 176  89 101 114 103 141 154 125 100 101 131 146 135 123 100 111 136
#  [19] 181 165 133 109  77  83 144 181 143 147  83 152 137 117 115  99 105 187
#  [37] 111 111 119  88  99 109 126 154  87 139 128 168  90  95 122 103  86 117
#  [55] 111 168 183 100  91  90  92  88 173  82 194 109 171 134 189 194 126 127
#  [73] 110  79 109  83 105 193 121 112 198 178 130 139 100 129  80 117 108 110
#  [91] 118 100  86  87  95 155 126 106 119 147 138 109 146  88 154 128 145 151
# [109] 131 167 100  87  93 109 107 111 123 165 125 144 102  95 148  78  78 125
# [127] 106  79 127 166 142 131 129 150  97 145  95 118  78 124 122 122 122  83
# [145]  71 180  96 157  84 189  84 139 150  95 181 111 109 139 102 120

# %% [markdown]
# ## Mean percentage error - percentage difference between predicted and actual values

# %%
mpe=((predicted-actual)/actual)
mean(mpe)*100
# Out:
# [1] 4.92899

# %% [markdown]
# ## EXERCISE
#
# ### pima-indians-diabetes2.csv contains the predictor variables for the test set.
# ### pima-indians-diabetes3.csv contains the dependent variables (or glucose readings) for the test set.
#
# ### Your task is to use the existing model to generate new predictions for this test set and calculate the mean percentage error on these new predictions.
#
# ### Run below for solution.

# %%
diabetes2<-read.csv("pima-indians-diabetes2.csv")
# Out:
# The following objects are masked from maxmindf:
#
#     Age, BloodPressure, BMI, DiabetesPedigreeFunction, Insulin,
#     Outcome, Pregnancies, SkinThickness

# %% [markdown]
# ## Max-Min Normalization

# %%
normalize <- function(x) {
  return ((x - min(x)) / (max(x) - min(x)))
}

maxmindf2 <- as.data.frame(lapply(diabetes2, normalize))
attach(maxmindf2)

# %% [markdown]
# ## Using the predict function in R, generate predictions (pred_test) for the Glucose variable using maxmindf2

# %%
pred_test <- data.frame(y = predict(model, as.matrix(maxmindf2)))
predicted_test = pred_test$y * abs(diff(range(diabetes1$Glucose))) + min(diabetes1$Glucose)
predicted_test
# Out:
#   [1] 147.91135 118.40756 161.89970 113.08413 165.86854 154.13147 137.16663
#   [8]  96.08984 144.15751  98.36231 120.92928 125.47944 129.58703  97.19640
#  [15] 137.81778 126.95209 106.22189 130.47553 154.61317 144.86311 114.25938
#  [22] 112.82496 122.00280 164.37180 127.44846 131.71429 122.46762 111.37986
#  [29] 113.02391 146.74795 119.00512 149.09657  94.65417 147.56126 128.44774
#  [36] 162.03779 124.39991 132.36136 109.78511 203.80471 128.09637 140.89610
#  [43] 148.29676 138.18542 154.32096 136.24980 184.06289 105.77952 134.63099
#  [50] 107.79164 137.99553 127.62033 114.97030 112.95559 132.21318 147.12653
#  [57] 137.50474 149.24263 120.46389 151.27392 103.77737 120.11020  95.59019
#  [64] 111.40643 117.57678 115.05230 126.54112 136.96068 115.00094 154.53131
#  [71]  98.19602 134.04912 102.02255 135.38160 116.87173 106.58268 164.65606
#  [78] 124.81205 125.63073 127.35589 138.80646 154.44435 135.58622 132.74860
#  [85] 134.33066 123.56725 133.66791 114.86663 133.74690 107.17576 107.20224
#  [92] 127.58452 109.69225 135.50422 115.52798 130.62762 121.95785 124.65872
#  [99] 139.45265 123.84268  91.87100 123.55730 164.52801 120.53490 145.92602
# [106]  94.90657 160.66971 112.31006 121.48159 155.61889 165.63780 109.98377
# [113] 129.36615 116.72250 119.53031 159.65762 121.35452 120.57856 128.88056
# [120] 133.74305 133.76619 113.85401 166.62619 107.13496 132.66533 134.24086
# [127] 163.52934 123.74579 183.41626 162.33348 114.42334 141.18417 109.32983
# [134] 114.75124 124.97797 129.08900 148.65746 145.74812 113.82892  98.96228
# [141] 161.60697 123.95102 129.68322 138.87049 141.63023 134.46038 141.14834
# [148] 110.03063 155.70737 135.29880 122.64693 140.27774 148.74362

# %% [markdown]
# ## Loading test set - or unseen data for this purpose

# %%
diabetes3<-read.csv("pima-indians-diabetes3.csv")
diabetes3
# Out:
#     Glucose
# 1    97
# 2    83
# 3   130
# 4   128
# 5   149
# 6   144
# 7   119
# 8   108
# 9   120
# 10  120
# 11  114
# 12  127
# 13  162
# 14  106
# 15   90
# 16   93
# 17  106
# 18  112
# 19  147
# 20  111
# 21  107
# 22  153
# 23  110
# 24  136
# 25  136
# 26  195
# 27  101
# 28   88
# 29  175
# 30  145
# ⋮   ⋮
# 124 102
# 125 102
# 126 106
# 127 174
# 128 121
# 129 142
# 130 145
# 131  80
# 132 112
# 133 122
# 134  95
# 135 141
# 136 106
# 137 101
# 138 140
# 139  94
# 140 111
# 141 129
# 142 112
# 143  94
# 144 156
# 145 128
# 146 162
# 147 158
# 148 132
# 149 168
# 150 129
# 151 137
# 152 199
# 153 138

# %% [markdown]
# ## Compare predicted values with actual values

# %%
actual_test = diabetes3$Glucose
df2<-data.frame(predicted_test,actual_test)
attach(df2)
df2
# Out:
# The following objects are masked _by_ .GlobalEnv:
#
#     actual_test, predicted_test
#     predicted_test actual_test
# 1   147.91135       97
# 2   118.40756       83
# 3   161.89970      130
# 4   113.08413      128
# 5   165.86854      149
# 6   154.13147      144
# 7   137.16663      119
# 8    96.08984      108
# 9   144.15751      120
# 10   98.36231      120
# 11  120.92928      114
# 12  125.47944      127
# 13  129.58703      162
# 14   97.19640      106
# 15  137.81778       90
# 16  126.95209       93
# 17  106.22189      106
# 18  130.47553      112
# 19  154.61317      147
# 20  144.86311      111
# 21  114.25938      107
# 22  112.82496      153
# 23  122.00280      110
# 24  164.37180      136
# 25  127.44846      136
# 26  131.71429      195
# 27  122.46762      101
# 28  111.37986       88
# 29  113.02391      175
# 30  146.74795      145
# ⋮   ⋮              ⋮
# 124 107.13496      102
# 125 132.66533      102
# 126 134.24086      106
# 127 163.52934      174
# 128 123.74579      121
# 129 183.41626      142
# 130 162.33348      145
# 131 114.42334       80
# 132 141.18417      112
# 133 109.32983      122
# 134 114.75124       95
# 135 124.97797      141
# 136 129.08900      106
# 137 148.65746      101
# 138 145.74812      140
# 139 113.82892       94
# 140  98.96228      111
# 141 161.60697      129
# 142 123.95102      112
# 143 129.68322       94
# 144 138.87049      156
# 145 141.63023      128
# 146 134.46038      162
# 147 141.14834      158
# 148 110.03063      132
# 149 155.70737      168
# 150 135.29880      129
# 151 122.64693      137
# 152 140.27774      199
# 153 148.74362      138

# %% [markdown]
# ## Mean percentage error calculation

# %%
mpe2=((predicted_test-actual_test)/actual_test)
mean(mpe2)*100
# Out:
# [1] 10.88506
