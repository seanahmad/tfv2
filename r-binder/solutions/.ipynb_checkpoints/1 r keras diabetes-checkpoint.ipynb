# %%
#devtools::install_github("rstudio/tensorflow")

# %%
library(tensorflow)
#install_tensorflow()

# %%
library(keras)
diabetes1<-read.csv("pima-indians-diabetes1.csv")

#Max-Min Normalization
normalize <- function(x) {
  return ((x - min(x)) / (max(x) - min(x)))
}

maxmindf <- as.data.frame(lapply(diabetes1, normalize))
attach(maxmindf)
maxmindf<-as.matrix(maxmindf)

# %%
ind <- sample(2, nrow(maxmindf), replace=TRUE, prob = c(0.7,0.3))

# Build X_train, y_train, X_val, y_val
X_train <- maxmindf[ind==1, 1:8]
X_val <- maxmindf[ind==2, 1:8]
y_train <- maxmindf[ind==1, 9]
y_val <- maxmindf[ind==2, 9]

# %%
model <- keras_model_sequential() 
model %>% 
  layer_dense(units = 12, activation = 'relu', kernel_initializer='RandomNormal', input_shape = c(8)) %>% 
  layer_dense(units = 8, activation = 'relu') %>%
  layer_dense(units = 1, activation = 'linear')

summary(model)
# Out:
# ________________________________________________________________________________
# Layer (type)                        Output Shape                    Param #
# ================================================================================
# dense (Dense)                       (None, 12)                      108
# ________________________________________________________________________________
# dense_1 (Dense)                     (None, 8)                       104
# ________________________________________________________________________________
# dense_2 (Dense)                     (None, 1)                       9
# ================================================================================
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# ________________________________________________________________________________

# %%
model %>% compile(
  loss = 'mean_squared_error',
  optimizer = 'adam',
  metrics = c('mae')
)

history <- model %>% fit(
  X_train, y_train, 
  epochs = 150, batch_size = 50, 
  validation_split = 0.2
)

# %%
model %>% evaluate(X_val, y_val)
model
pred <- data.frame(y = predict(model, as.matrix(X_val)))
predicted=pred$y * abs(diff(range(diabetes1$Glucose))) + min(diabetes1$Glucose)
actual=y_val * abs(diff(range(diabetes1$Glucose))) + min(diabetes1$Glucose)
df<-data.frame(predicted,actual)
attach(df)
# Out:
# $loss
# [1] 0.02751621
#
# $mean_absolute_error
# [1] 0.1339114
# Model
# ________________________________________________________________________________
# Layer (type)                        Output Shape                    Param #
# ================================================================================
# dense (Dense)                       (None, 12)                      108
# ________________________________________________________________________________
# dense_1 (Dense)                     (None, 8)                       104
# ________________________________________________________________________________
# dense_2 (Dense)                     (None, 1)                       9
# ================================================================================
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# ________________________________________________________________________________
# The following objects are masked _by_ .GlobalEnv:
#
#     actual, predicted

# %%
predicted=as.matrix(predicted)
predicted
# Out:
#       [,1]
#  [1,] 103.97535
#  [2,] 146.57623
#  [3,] 146.13908
#  [4,] 145.57141
#  [5,]  95.75568
#  [6,] 138.19103
#  [7,]  99.96596
#  [8,] 103.65094
#  [9,] 103.59380
# [10,]  99.00091
# [11,] 131.68510
# [12,] 112.36995
# [13,] 144.11094
# [14,] 108.97651
# [15,] 100.37070
# [16,] 121.66740
# [17,] 129.33278
# [18,] 138.59583
# [19,] 136.51122
# [20,]  97.30940
# [21,] 142.73851
# [22,]  98.81599
# [23,]  98.65746
# [24,] 145.52019
# [25,] 111.52029
# [26,] 145.45076
# [27,] 130.13502
# [28,] 106.65760
# [29,] 135.23940
# [30,] 132.81304
# [31,] ⋮
# [32,] 132.74538
# [33,] 152.30201
# [34,] 113.94921
# [35,] 105.20193
# [36,] 126.35783
# [37,] 102.36537
# [38,] 140.47052
# [39,] 105.30287
# [40,] 127.14128
# [41,]  96.12434
# [42,] 125.95052
# [43,]  98.97319
# [44,] 109.24026
# [45,] 107.92518
# [46,] 107.92315
# [47,] 136.76271
# [48,] 124.82714
# [49,] 103.98408
# [50,] 156.27059
# [51,] 113.15163
# [52,] 123.71527
# [53,] 115.98572
# [54,] 104.01707
# [55,] 108.35663
# [56,] 131.69366
# [57,] 150.04557
# [58,] 112.81257
# [59,] 106.84972
# [60,] 118.70392
# [61,] 141.65459

# %%
actual
# Out:
#   [1]  72 146 158 176 101 189  76  87  98 103 129 106 108 125  71 154 163 143
#  [19] 125  83 180 101 101 131  77 146 100 116 168 162  77  97  83 179 162 143
#  [37]  96 119 128 143 152  73 100  57 132 114 116  99 128 187 119 125  99  84
#  [55]  97  90  87 139 111  84 134 173 113  99 119 144 100 102 120 105 173 194
#  [73] 128  99 175 101 100 194 135 166  79  83 196  97 105 170  95 163  93 123
#  [91] 105 121 178 130 143 139 122 133  99  80  96 136 133 151  86  85  88 147
# [109] 124 108 106 162 128 197 129 132  85 140 134 110 109  88 141 172 123  85
# [127] 151 103  81  99 167 100  87 147 117 111 125  78 136  88  78 100 106  95
# [145]  95  68 117 119 131 151  97 132 103 187 165 118 183  78 186 109 123  80
# [163] 131 125 112  83 106  78 126  85 115 157  84  99 103  90 188 150 131 139
# [181] 112 120

# %%
mpe=((predicted-actual)/actual)
mean(mpe)*100
# Out:
# [1] 5.638604

# %%
diabetes2<-read.csv("pima-indians-diabetes2.csv")

#Max-Min Normalization
normalize <- function(x) {
  return ((x - min(x)) / (max(x) - min(x)))
}

maxmindf2 <- as.data.frame(lapply(diabetes2, normalize))
attach(maxmindf2)
# Out:
# The following objects are masked from maxmindf:
#
#     Age, BloodPressure, BMI, DiabetesPedigreeFunction, Insulin,
#     Outcome, Pregnancies, SkinThickness

# %%
pred_test <- data.frame(y = predict(model, as.matrix(maxmindf2)))
predicted_test = pred_test$y * abs(diff(range(diabetes1$Glucose))) + min(diabetes1$Glucose)
predicted_test
# Out:
#   [1] 141.61273 111.86105 143.52109 110.92027 155.37283 149.92965 112.04527
#   [8] 102.60819 127.55024  99.86796 129.69521 123.08190 128.11404  99.98121
#  [15] 124.76006 111.50786  98.29298 131.76534 144.49055 159.18707 113.94135
#  [22] 136.53064 122.10908 171.68392 125.42681 129.63381 165.82208  99.97760
#  [29] 102.62937 179.93233 112.49331 108.91849 150.21057 160.26236 153.17825
#  [36] 145.46546 112.60164 107.50700 111.63592 112.98757 109.45418 118.29153
#  [43] 153.24926 140.82419 177.31914 128.60827 167.75067  94.62625 111.33789
#  [50] 107.76447 121.76295 161.61032 127.31362 114.70801 109.46733 112.09450
#  [57] 124.33571 134.06866 147.28322 156.67549  97.16442 125.40795  98.22596
#  [64] 104.23380 111.01070 108.81471 165.43237 155.41338 137.59639 155.41968
#  [71] 100.01215 135.12952  95.13655 181.58284 107.27772 106.33843 143.90780
#  [78] 131.63266 123.85627 108.55081 120.58711 160.11144 186.87785 151.34753
#  [85] 120.41506 140.76049 106.79329  93.20472 155.60701 112.78069 103.51631
#  [92] 122.21567 114.19399 146.57625 106.21910 128.27985 136.18360 114.77963
#  [99] 139.35628 113.11415  97.64007 109.18251 114.04699 119.76739 155.76195
# [106] 100.90258 140.00907 117.31935 123.90765 137.38845 152.52740 100.98647
# [113] 133.72102 116.40624 133.96153 186.30772 140.05263 136.60899 126.46497
# [120] 120.39185 149.08879 109.64495 146.30436 104.86903 183.10544 112.27487
# [127] 141.55586 119.70882 163.43698 167.03473 123.30798 162.26637 114.31909
# [134] 117.20277 110.04845 120.62538 107.92707 103.40080 110.30862  94.39712
# [141] 170.62467 123.68375 136.95037 159.97612 121.50157 151.34068 154.34547
# [148]  97.71666 151.66715 123.02201 128.67789 140.72583 156.63013

# %%
diabetes3<-read.csv("pima-indians-diabetes3.csv")
diabetes3
# Out:
#     Glucose
# 1    97
# 2    83
# 3   130
# 4   128
# 5   149
# 6   144
# 7   119
# 8   108
# 9   120
# 10  120
# 11  114
# 12  127
# 13  162
# 14  106
# 15   90
# 16   93
# 17  106
# 18  112
# 19  147
# 20  111
# 21  107
# 22  153
# 23  110
# 24  136
# 25  136
# 26  195
# 27  101
# 28   88
# 29  175
# 30  145
# ⋮   ⋮
# 124 102
# 125 102
# 126 106
# 127 174
# 128 121
# 129 142
# 130 145
# 131  80
# 132 112
# 133 122
# 134  95
# 135 141
# 136 106
# 137 101
# 138 140
# 139  94
# 140 111
# 141 129
# 142 112
# 143  94
# 144 156
# 145 128
# 146 162
# 147 158
# 148 132
# 149 168
# 150 129
# 151 137
# 152 199
# 153 138

# %%
actual_test = diabetes3$Glucose
df2<-data.frame(predicted_test,actual_test)
attach(df2)
df2
# Out:
# The following objects are masked _by_ .GlobalEnv:
#
#     actual_test, predicted_test
#     predicted_test actual_test
# 1   141.61273       97
# 2   111.86105       83
# 3   143.52109      130
# 4   110.92027      128
# 5   155.37283      149
# 6   149.92965      144
# 7   112.04527      119
# 8   102.60819      108
# 9   127.55024      120
# 10   99.86796      120
# 11  129.69521      114
# 12  123.08190      127
# 13  128.11404      162
# 14   99.98121      106
# 15  124.76006       90
# 16  111.50786       93
# 17   98.29298      106
# 18  131.76534      112
# 19  144.49055      147
# 20  159.18707      111
# 21  113.94135      107
# 22  136.53064      153
# 23  122.10908      110
# 24  171.68392      136
# 25  125.42681      136
# 26  129.63381      195
# 27  165.82208      101
# 28   99.97760       88
# 29  102.62937      175
# 30  179.93233      145
# ⋮   ⋮              ⋮
# 124 104.86903      102
# 125 183.10544      102
# 126 112.27487      106
# 127 141.55586      174
# 128 119.70882      121
# 129 163.43698      142
# 130 167.03473      145
# 131 123.30798       80
# 132 162.26637      112
# 133 114.31909      122
# 134 117.20277       95
# 135 110.04845      141
# 136 120.62538      106
# 137 107.92707      101
# 138 103.40080      140
# 139 110.30862       94
# 140  94.39712      111
# 141 170.62467      129
# 142 123.68375      112
# 143 136.95037       94
# 144 159.97612      156
# 145 121.50157      128
# 146 151.34068      162
# 147 154.34547      158
# 148  97.71666      132
# 149 151.66715      168
# 150 123.02201      129
# 151 128.67789      137
# 152 140.72583      199
# 153 156.63013      138

# %%
mpe2=((predicted_test-actual_test)/actual_test)
mean(mpe2)*100
# Out:
# [1] 9.302855
